# %% [markdown]
# # KyFromAbove Explorer November Stats
#
# This project takes data from an AWS Athena DataCatalog database table for the [KyFromAbove Open Data on AWS](https://registry.opendata.aws/kyfromabove/) from the [KyFromAbove Exploerer](https://explore.kyfromabove.ky.gov/) for the month of November.  For simplicity and security reasons, I performed the query in Athena and just exported the results to CSV.  This way, I'm not providing access to AWS, plus not having to query, paginate, and refresh a token.
#
# ```sql
#     SELECT * FROM "s3_access_logs_db"."kyfromabove_monthly"
#     WHERE "year" = '2024'
#     AND "month" = '11';
# ```

# %% [markdown]
# ## Project Questions
#
#  - How many GET requests is the KyFromAbove S3 Bucket receiving from the KyFromAbove Explorer.
#  - How many bytes are getting sent?
#  - What are the most popular images?
#  - Who is using the data?

# %% [markdown]
# ___
#
# ## Read the data using pandas

# %%
import pandas as pd

# %%
# add my csv file path
csv_file = './97d9edc8-c0c4-4f42-b7b2-fe8c8e11ee8f.csv'

# read as a dataframe
logs = pd.read_csv(
    csv_file, 
    header=0, 
    dtype=
    {'httpstatus': str,  # columns 9 & 13 popped out as mixed Dtype
     'totaltime': str    # so I just assigned them as strings
    }
)

# %% [markdown]
# #### Drop columns

# %%
logs.columns
# Out:
# Index(['bucketowner', 'bucket_name', 'requestdatetime', 'remoteip',
#        'requester', 'requestid', 'operation', 'key', 'request_uri',
#        'httpstatus', 'errorcode', 'bytessent', 'objectsize', 'totaltime',
#        'turnaroundtime', 'referrer', 'useragent', 'versionid', 'hostid',
#        'sigv', 'ciphersuite', 'authtype', 'endpoint', 'tlsversion',
#        'accesspointarn', 'aclrequired', 'year', 'month'],
#       dtype='object')

# %% [markdown]
# Since I know that the values for `bucketowner` and `bucket_name` will be the same for all rows, I can drop those two.  Also, because this database table is partitioned based on `year` and`month`, I can drop these values.
#
# I also know that I'm looking for requests that come from the KyFromAbove Explorer, so I will also filter the dataframe for values `referrer=https://explore.kyfromabove.ky.gov/`

# %%
# drop bucketowner, bucket_name, year, and month
logs = logs.drop(['bucketowner', 'bucket_name', 'year', 'month'], axis=1)

# filter for the referrer
logs_filtered = logs[logs['referrer'] == '"https://explore.kyfromabove.ky.gov/"']

# print the head and tail to view table
print(f'The unfiltered dataset has this for it"s shape value: {logs.shape}\n')
print(f'The filtered dataset as a shape value of: {logs_filtered.shape}\n')  # just to get an idea of the data
logs_filtered
# Out:
# The unfiltered dataset has this for it"s shape value: (6612895, 24)
#
# The filtered dataset as a shape value of: (1834294, 24)
#                     requestdatetime      remoteip requester         requestid  \
# 0        01/Nov/2024:14:51:04 +0000  162.211.36.0         -  DVH2XBFQTQEH3NJ2
# 1        01/Nov/2024:14:51:04 +0000  162.211.36.0         -  DVH61VS2E85ZB0R4
# 2        01/Nov/2024:14:51:04 +0000  162.211.36.0         -  DVHA123N17KNX3H6
# 3        01/Nov/2024:14:51:05 +0000  162.211.36.0         -  BX6PD6E7GYYVTE57
# 14       01/Nov/2024:15:11:51 +0000   65.34.46.11         -  W0C27ZNMP1SGM8TY
# ...                             ...           ...       ...               ...
# 6612058  30/Nov/2024:18:39:55 +0000  76.35.248.15         -  GNTNA6KN6D3MDG34
# 6612059  30/Nov/2024:18:39:56 +0000  76.35.248.15         -  MSCXY8PW66XSPZHQ
# 6612060  30/Nov/2024:17:43:11 +0000  76.35.248.15         -  79H1PBZNDRF0VPEW
# ...

# %%
# check the columns
logs_filtered.columns
# Out:
# Index(['requestdatetime', 'remoteip', 'requester', 'requestid', 'operation',
#        'key', 'request_uri', 'httpstatus', 'errorcode', 'bytessent',
#        'objectsize', 'totaltime', 'turnaroundtime', 'referrer', 'useragent',
#        'versionid', 'hostid', 'sigv', 'ciphersuite', 'authtype', 'endpoint',
#        'tlsversion', 'accesspointarn', 'aclrequired'],
#       dtype='object')

# %% [markdown]
# #### Drop more columns
#
# After review, we can drop requestid, errorcode, versionid, hostid, sigv, ciphersuite, authtype, tlsversion, accesspointarn, aclrequired and of course, referrer.  These valuse don't mean anything regarding the questions I'm asking.

# %%
logs_filtered = logs_filtered.drop([
    'requestid', 'errorcode', 'versionid', 'hostid', 'sigv', 'ciphersuite', 'authtype',
    'tlsversion', 'accesspointarn', 'aclrequired', 'referrer'],
    axis=1)

print(logs_filtered.shape)
logs_filtered.head()
# Out:
# (1834294, 13)
#                requestdatetime      remoteip requester        operation  \
# 0   01/Nov/2024:14:51:04 +0000  162.211.36.0         -  REST.GET.OBJECT
# 1   01/Nov/2024:14:51:04 +0000  162.211.36.0         -  REST.GET.OBJECT
# 2   01/Nov/2024:14:51:04 +0000  162.211.36.0         -  REST.GET.OBJECT
# 3   01/Nov/2024:14:51:05 +0000  162.211.36.0         -  REST.GET.OBJECT
# 14  01/Nov/2024:15:11:51 +0000   65.34.46.11         -  REST.GET.OBJECT
#
#                                                   key  \
# 0   imagery/obliques/Phase3/KY_KYAPED_2024_Season1...
# 1   imagery/obliques/Phase3/KY_KYAPED_2024_Season1...
# 2   imagery/obliques/Phase3/KY_KYAPED_2024_Season1...
# 3   imagery/obliques/Phase3/KY_KYAPED_2024_Season1...
# 14  imagery/obliques/Phase3/KY_KYAPED_2023_Season2...
#
#                                           request_uri httpstatus  bytessent  \
# 0   "GET /imagery/obliques/Phase3/KY_KYAPED_2024_S...        206    65536.0
# ...

# %% [markdown]
# #### More review, drop more columns
#
# Looking at the dataframe above, I can see a few things that aren't really necessary.  We can filter "GET" from operation or request_uri.  I'll drop request_uri because it has a lot less characters and could probably save a little memory space.  Also, because of the earlier filter of referrer, the endpoint is likely the same for all rows.  The requester probably isn't necessary either, since it's requesting from a uri and not an actual user client.
#
# Object size isn't too important, but I can leave it in for some easy calculations (eg., object size / bytes sent or object size / totaltime or turnaround time)

# %%
# drop request_uri, endpoint, and requestor
logs_filtered = logs_filtered.drop(['request_uri', 'endpoint', 'requester'], axis=1)
print(f'Dataframe Shape Values: {logs_filtered.shape}\n')
logs_filtered.columns
# Out:
# Dataframe Shape Values: (1834294, 10)
# Index(['requestdatetime', 'remoteip', 'operation', 'key', 'httpstatus',
#        'bytessent', 'objectsize', 'totaltime', 'turnaroundtime', 'useragent'],
#       dtype='object')

# %% [markdown]
# ___
#
# ## Data Cleaning and Preparation
#
# In this section, I'm going to format the `requestdatetime` values so that it's just a day/month/year without a time stamp.
#
#
#
# #### Create a new column
#
# AWS S3 stores files as objects with bucket for location key as the name of the file.  This means a key could have several prefixes (analogous to folder or directory) on it's front end.  For example, for the key *imagery/obliques/Phase3/KY_KYAPED_2022_Season2_3IN/Bwd_2025_401340.tif* I eventually want to know the actual file name: *Bwd_2025_401340.tif*

# %%
# format the requestdatetime column
